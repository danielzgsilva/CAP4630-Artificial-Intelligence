# %% [markdown]
# # CAP4630 Assignment 1

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import gridspec
import numpy as np
from mpl_toolkits import mplot3d
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %% [markdown]
# ## Problem 1 - Plotting

# %%
# Define a function to find the minimum of
def f_min(x,y):
  return y**2 + x**2

# %%
# Creating points to plot
x = np.arange(-1, 1, 0.1)
y = np.arange(-1, 1, 0.1)

x_grid, y_grid = np.meshgrid(x, y)
z_grid = f_min(x_grid, y_grid)

# %%
plt.scatter(x = [0], y = [0], s=200, color='red')
plt.imshow(z_grid, extent=[min(x), max(x), min(y), max(y)], origin='lower',
           cmap='RdGy')
plt.colorbar()
plt.title('Minimum')
plt.axis(aspect='image');

# %%
ax = plt.axes(projection='3d')
ax.scatter(xs = [0], ys = [0], zs = [0], s=200, color='red')
ax.plot_surface(x_grid, y_grid, z_grid, cmap='viridis', edgecolor='none', alpha=0.7)
ax.set_title('Minimum')
plt.show()

# %%
# Define a function to find a saddle point in
def f_saddle(x,y):
  return y**2 - x**2

# %%
# Creating points to plot
x = np.arange(-1, 1, 0.1)
y = np.arange(-1, 1, 0.1)

x_grid, y_grid = np.meshgrid(x, y)
z_grid = f_saddle(x_grid, y_grid)

# %%
plt.scatter(x = [0], y = [0], s=200, color='red')
plt.imshow(z_grid, extent=[min(x), max(x), min(y), max(y)], origin='lower',
           cmap='RdGy')
plt.colorbar()
plt.title('Maximum')
plt.axis(aspect='image');

# %%
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs = [0], ys = [0], zs = [0], s=200, color='red')
ax.plot_surface(x_grid, y_grid, z_grid, cmap='viridis', edgecolor='none', alpha=0.6)
ax.set_title('Saddle Point')
plt.show()

# %%
# Define a function to find the maximum of
def f_max(x,y):
  return (np.cos(y) + np.cos(x))

# %%
# Creating points to plot
x = np.arange(-5, 5, 0.5)
y = np.arange(-5, 5, 0.5)

x_grid, y_grid = np.meshgrid(x, y)
z_grid = f_max(x_grid, y_grid)

# %%
plt.scatter(x = [0], y = [0], s=200, color='red')
plt.imshow(z_grid, extent=[min(x), max(x), min(y), max(y)], origin='lower',
           cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image');

# %%
ax = plt.axes(projection='3d')
ax.scatter(xs = [0], ys = [0], zs = [2], s=200, color='red')
ax.plot_surface(x_grid, y_grid, z_grid, cmap='viridis', edgecolor='none', alpha=0.6)
ax.set_title('Maximum')
plt.show()
